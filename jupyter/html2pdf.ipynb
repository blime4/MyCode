# %%
import requests
from bs4 import BeautifulSoup
html = requests.get("https://www.captainbed.net/")
soup = BeautifulSoup(html.text)
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="zh-CN">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="http://microformats.org/profile/specs" rel="profile"/>
# <link href="http://microformats.org/profile/hatom" rel="profile"/>
# <script>(function(html){html.className = html.className.replace(/\bno-js\b/,'js')})(document.documentElement);</script>
# <title>床长人工智能教程 - 床长人工智能教程</title>
# <!-- This site is optimized with the Yoast SEO plugin v11.5 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="床长人工智能教程——史上最风骚最通俗易懂的人工智能教程。零基础，通俗易懂，风趣幽默。带领无数人进入人工智能领域的大神之作！" name="description"/>
# <link href="https://www.captainbed.net/" rel="canonical"/>
# <meta content="zh_CN" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="床长人工智能教程 - 床长人工智能教程" property="og:title"/>
# ...

# %%
! pip install Bs4 --user
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/35/e3/25079e8911085ab76a6f2facae0771078260c930216ab0b0c44dc5c9bf31/soupsieve-1.9.2-py2.py3-none-any.whl
# ...
